# %% [markdown]
# # Importing Overture data from Parquet
#
# The [Overture foundation/project](https://overturemaps.org/download/) has developed a novel dataset that serves as a supplement to OpenStreetMap. There is a lot more to it, so please check out the link above.
#
# This notebook will highlight how to parse their open data into GeoPandas Dataframes

# %%
import sys, os, importlib
import rasterio, geojson

import pandas as pd
import geopandas as gpd

from sedona.spark import * 

# %load_ext autoreload
# %autoreload 2
# Out:
# /home/wb411133/.conda/envs/ee/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
config = SedonaContext.builder().config("fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.AnonymousAWSCredentialsProvider").getOrCreate()
sedona = SedonaContext.create(config)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-9-58ec750ec4c3> in <module>
#       1 config = SedonaContext.builder().config("fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.AnonymousAWSCredentialsProvider").getOrCreate()
# ----> 2 sedona = SedonaContext.create(config)
#       3
#
# ~/.conda/envs/ee/lib/python3.9/site-packages/sedona/spark/SedonaContext.py in create(cls, spark)
#      34         :return: SedonaContext which is an instance of SparkSession
#      35         """
# ---> 36         spark.sql("SELECT 1 as geom").count()
#      37         PackageImporter.import_jvm_lib(spark._jvm)
#      38         spark._jvm.SedonaContext.create(spark._jsparkSession)
#
# ~/.conda/envs/ee/lib/python3.9/site-packages/pyspark/sql/dataframe.py in count(self)
#    1191         3
#    1192         """
# -> 1193         return int(self._jdf.count())
#    1194
# ...

# %%
df = sedona.read.format("parquet").load("s3a://overturemaps-us-west-2/release/2023-07-26-alpha.0/theme=buildings/type=building")

# %%
tempDF = gpd.read_parquet("s3://overturemaps-us-west-2/release/2023-07-26-alpha.0/theme=buildings/type=building")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-7670e3b6016b> in <module>
# ----> 1 tempDF = gpd.read_parquet("s3://overturemaps-us-west-2/release/2023-07-26-alpha.0/theme=buildings/type=building")
#
# ~/.conda/envs/ee/lib/python3.9/site-packages/geopandas/io/arrow.py in _read_parquet(path, columns, **kwargs)
#     391
#     392     kwargs["use_pandas_metadata"] = True
# --> 393     table = parquet.read_table(path, columns=columns, **kwargs)
#     394
#     395     return _arrow_to_geopandas(table)
#
# ~/.conda/envs/ee/lib/python3.9/site-packages/pyarrow/parquet.py in read_table(source, columns, use_threads, metadata, use_pandas_metadata, memory_map, read_dictionary, filesystem, filters, buffer_size, partitioning, use_legacy_dataset, ignore_prefixes)
#    1698             )
#    1699         try:
# -> 1700             dataset = _ParquetDatasetV2(
# ...
